# %% [markdown]
# # importing libraries, files, etc.

# %%
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle
import csv

from trip import Trip
import transform as tf
import data_processing as dp

# %matplotlib inline

# %%
reload(dp)
reload(tf)
# Out:
# <module 'transform' from 'transform.pyc'>

# %% [markdown]
# Constants to be used throughout.

# %%
trips_per_driver = 200
drivers_per_pickle = 48
num_pickle = 57

# %% [markdown]
# # creating trip objects for analysis

# %% [markdown]
# Choose driver index for classification.

# %%
driver_index = 0
driver_index_mod = driver_index % 57
drivers_file = 'driverData_'+str(int(driver_index)/57)+'.p'

# %%
with open(drivers_file, 'r') as f:
    drivers = pickle.load(f)
driver = drivers[driver_index_mod]
del drivers

# %%
trips = [Trip(driver_index, i, driver[i]) for i in range(trips_per_driver)]

# %% [markdown]
# # spacial similarity

# %% [markdown]
# Transform all the trips by rotating to x-axis.

# %%
trips_rotated = [Trip(driver_index, i, tf.rotate_x_axis(trips[i].coordinates)) for i in range(trips_per_driver)]

# %% [markdown]
# Comparison algorithm to get sets of similar trips.

# %%
def set_compare(stuff, threshold):
    sets_dict = {}
    no_matches = set(stuff)

    for a in stuff:
        if a in no_matches:
            search_from = no_matches | set(sets_dict.keys())
            for b in search_from:
                if a != b and abs(len(a.coordinates)-len(b.coordinates))/float(len(a.coordinates)) < 0.2: # cannot differ too much
                    if (dp.distance(a, b) <= threshold and max([x[0] for x in a.coordinates]) > 1000
                        and max([x[0] for x in b.coordinates]) > 1000):
                            sets_dict.setdefault(a, set([a])).add(b)
                            no_matches.discard(a)
                            no_matches.discard(b)
    
    return sets_dict, no_matches

# %% [markdown]
# Optional: select sets of certain size.

# %%
def set_select(sets, threshold):
    new_sets = []
    
    if threshold < 1 and threshold > 0:
        new_sets = sorted([len(s) for s in sets])[:len(sets)*threshold]
        
    elif threshold > 1:
        for s in sets:
            if len(s) > threshold:
                new_sets.append(s)
    
    return new_sets

# %% [markdown]
# Find distances between all trips and takes those that have at least one match.

# %%
true_sets = set_compare(trips_rotated, 100)[0]
true_trips = list(set().union(*true_sets.values()))
# Out:
# [<trip.Trip instance at 0x0000000034BBC808>, <trip.Trip instance at 0x00000000368C3908>, <trip.Trip instance at 0x00000000219A2848>, <trip.Trip instance at 0x000000002FE68888>, <trip.Trip instance at 0x000000002FA0FAC8>, <trip.Trip instance at 0x000000003811C108>, <trip.Trip instance at 0x000000002F860988>, <trip.Trip instance at 0x00000000382C2848>, <trip.Trip instance at 0x000000002ECA9548>, <trip.Trip instance at 0x0000000028D63588>, <trip.Trip instance at 0x00000000365F2848>, <trip.Trip instance at 0x0000000037EE61C8>, <trip.Trip instance at 0x00000000397DCE08>, <trip.Trip instance at 0x0000000031FCEB08>, <trip.Trip instance at 0x000000002A6B5D88>, <trip.Trip instance at 0x0000000028CF5A48>, <trip.Trip instance at 0x0000000031BC1E88>, <trip.Trip instance at 0x0000000028DD6FC8>, <trip.Trip instance at 0x0000000031BEC2C8>, <trip.Trip instance at 0x0000000028D60B08>, <trip.Trip instance at 0x0000000021A2E288>, <trip.Trip instance at 0x0000000029B79588>, <trip.Trip instance at 0x0000000032A5CBC8>, <trip.Trip instance at 0x000000002F6351C8>, <trip.Trip instance at 0x0000000031DE4B88>, <trip.Trip instance at 0x000000003041FBC8>, <trip.Trip instance at 0x0000000031E16848>, <trip.Trip instance at 0x00000000363E63C8>]

# %% [markdown]
# Optional: plot trips in each set for visual verification.

# %%
for s in true_sets:
    if len(true_sets[s]) == 2:
        for x in true_sets[s]:
            plt.plot(x.x_coordinates, x.y_coordinates)
        plt.show()

# %% [markdown]
# # create training sets

# %% [markdown]
# Selecting false trips. Be careful, get_false_trips opens a large file and may slow down performance.

# %%
false_trips = dp.get_false_trips(len(true_matrix), driver_index)

# %%
true_labels, false_labels = dp.label_trips(true_trips, false_trips)

# %% [markdown]
# Create training matrix and labels.

# %%
training = zip(true_trips, true_labels) + zip(false_trips, false_labels)
training = np.random.permutation(training)

train_matrix = [n[0] for n in training]
train_labels = [n[1] for n in training]

# %% [markdown]
# # svm and prediction

# %%
c = 1
results = dp.run_SVM(train_matrix, train_labels, c, trips)

# %% [markdown]
# Write predictions to csv. Final submission form.

# %%
file_name = 'submission_0'
with open('submission_0.csv', 'wb') as f:
    writer = csv.writer(f)
    writer.writerow(['driver_trip', 'prob'])
    for i in range(1, len(results)+1):
        writer.writerow([str(driver_index+1)+'_'+str(i), results[i-1]])
